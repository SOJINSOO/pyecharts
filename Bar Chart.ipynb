# %% [markdown]
# # 1. Bar

# %% [markdown]
# ### - pyecharts Install

# %%
! pip install pyecharts
# Out:
# ...
#   Running setup.py bdist_wheel for jupyter-echarts-pypkg: started
#   Running setup.py bdist_wheel for jupyter-echarts-pypkg: finished with status 'done'
#   Stored in directory: C:\Users\SOJINSOO\AppData\Local\pip\Cache\wheels\62\5c\66\e79276e15e377da9854521c19718ac5a23d827a1b554cf0091
#   Running setup.py bdist_wheel for javascripthon: started
#   Running setup.py bdist_wheel for javascripthon: finished with status 'done'
#   Stored in directory: C:\Users\SOJINSOO\AppData\Local\pip\Cache\wheels\f0\a0\6e\5cac90791fefe9c2961f9d5b2fc9b71da8b9b2f927f4012918
#   Running setup.py bdist_wheel for macropy3: started
#   Running setup.py bdist_wheel for macropy3: finished with status 'done'
#   Stored in directory: C:\Users\SOJINSOO\AppData\Local\pip\Cache\wheels\ef\ea\95\65744a6a720d5b0b57779da564c68a3e1b221ea998542a78b3
# Successfully built jupyter-echarts-pypkg javascripthon macropy3
# ...
# jupyter-echarts-pypkg 0.1.2 requires pyecharts-jupyter-installer==0.0.3, which is not installed.

# %% [markdown]
# ### - Load Packages

# %%
import random
from pyecharts import Bar

# %% [markdown]
# ### - Data Setting

# %%
CLOTHES = ["셔츠", "스웨터", "블라우스", "바지", "하이힐", "양말"]

clothes_v1 = [5, 20, 36, 10, 75, 90]
clothes_v2 = [10, 25, 8, 60, 20, 80]

# %% [markdown]
# ### 1. bar stack

# %%
bar = Bar()
bar.add("가게A", CLOTHES, clothes_v1, is_stack=True)
bar.add("가게B", CLOTHES, clothes_v2, is_stack=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="75777e37e3804cc3b1323ef11be8af40" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_75777e37e3804cc3b1323ef11be8af40 = echarts.init(document.getElementById('75777e37e3804cc3b1323ef11be8af40'), 'light', {renderer: 'canvas'});
#
# var option_75777e37e3804cc3b1323ef11be8af40 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
# ...

# %% [markdown]
# ### 2. bar marks

# %%
bar = Bar("mark point 및 mark line 예시")
bar.add("가게A", CLOTHES, clothes_v1, mark_point=["average"])
bar.add("가게B", CLOTHES, clothes_v2, mark_line=["min", "max"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="91ea1a9b965c4df7b0d1cec3c62495e7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_91ea1a9b965c4df7b0d1cec3c62495e7 = echarts.init(document.getElementById('91ea1a9b965c4df7b0d1cec3c62495e7'), 'light', {renderer: 'canvas'});
#
# var option_91ea1a9b965c4df7b0d1cec3c62495e7 = {
#     "title": [
#         {
#             "text": "mark point \ubc0f mark line \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 3. bar convert xy axis

# %%
bar = Bar("x 축과 y 축 전환")
bar.add("가게A", CLOTHES, clothes_v1)
bar.add("가게B", CLOTHES, clothes_v2, is_convert=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9a414e951a1c48549c4e3354d9a5ee7c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9a414e951a1c48549c4e3354d9a5ee7c = echarts.init(document.getElementById('9a414e951a1c48549c4e3354d9a5ee7c'), 'light', {renderer: 'canvas'});
#
# var option_9a414e951a1c48549c4e3354d9a5ee7c = {
#     "title": [
#         {
#             "text": "x \ucd95\uacfc y \ucd95 \uc804\ud658",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 4. bar histogram

# %%
bar = Bar("Histogram 예시")
bar.add("", CLOTHES * 2, clothes_v1 + clothes_v2, bar_category_gap=0)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fc20cdf26acf40b29b52ad48918b201a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fc20cdf26acf40b29b52ad48918b201a = echarts.init(document.getElementById('fc20cdf26acf40b29b52ad48918b201a'), 'light', {renderer: 'canvas'});
#
# var option_fc20cdf26acf40b29b52ad48918b201a = {
#     "title": [
#         {
#             "text": "Histogram \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 5. bar rotate label

# %%
days = ["{}일".format(i) for i in range(20)]
days_v1 = [random.randint(1, 20) for _ in range(20)]
bar = Bar("축 레이블 회전 예시")
bar.add("", days, days_v1, xaxis_interval=0, xaxis_rotate=30, yaxis_rotate=30)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="41d70c18a3bd440da3866e60c6f1a6cc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_41d70c18a3bd440da3866e60c6f1a6cc = echarts.init(document.getElementById('41d70c18a3bd440da3866e60c6f1a6cc'), 'light', {renderer: 'canvas'});
#
# var option_41d70c18a3bd440da3866e60c6f1a6cc = {
#     "title": [
#         {
#             "text": "\ucd95 \ub808\uc774\ube14 \ud68c\uc804 \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ### 6. bar waterfall

# %%
months = ["{}월".format(i) for i in range(1, 8)]
months_v1 = [0, 100, 200, 300, 400, 220, 250]
months_v2 = [1000, 800, 600, 500, 450, 400, 300]
bar = Bar("Waterfall 예시")
bar.add("", months, months_v1, label_color=["rgba(0,0,0,0)"], is_stack=True)
bar.add(
    "월",
    months,
    months_v2,
    is_label_show=True,
    is_stack=True,
    label_pos="inside",
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="05aaa06c02464e51881b8cc6abcff0e5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_05aaa06c02464e51881b8cc6abcff0e5 = echarts.init(document.getElementById('05aaa06c02464e51881b8cc6abcff0e5'), 'light', {renderer: 'canvas'});
#
# var option_05aaa06c02464e51881b8cc6abcff0e5 = {
#     "title": [
#         {
#             "text": "Waterfall \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 7. bar datazoom undefined

# %%
days = ["{}일".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom 묵시적 예시")
bar.add("", days, days_v1, is_label_show=True, is_datazoom_show=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="70c78a6aa52a4142a215077ad52d7e2f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_70c78a6aa52a4142a215077ad52d7e2f = echarts.init(document.getElementById('70c78a6aa52a4142a215077ad52d7e2f'), 'light', {renderer: 'canvas'});
#
# var option_70c78a6aa52a4142a215077ad52d7e2f = {
#     "title": [
#         {
#             "text": "Bar - datazoom \ubb35\uc2dc\uc801 \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 8. bar datazoom slider

# %%
days = ["{}일".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom 예시")
bar.add(
    "",
    days,
    days_v1,
    is_datazoom_show=True,
    datazoom_type="slider",
    datazoom_range=[10, 25],
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="192ea97512584f6bb84fe3263388ad52" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_192ea97512584f6bb84fe3263388ad52 = echarts.init(document.getElementById('192ea97512584f6bb84fe3263388ad52'), 'light', {renderer: 'canvas'});
#
# var option_192ea97512584f6bb84fe3263388ad52 = {
#     "title": [
#         {
#             "text": "Bar - datazoom \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 9. bar datazoom inside

# %%
days = ["{}일".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - inside 예시")
bar.add(
    "",
    days,
    days_v1,
    is_datazoom_show=True,
    datazoom_type="inside",
    datazoom_range=[10, 25],
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="14f16df8d0154f0aa2e7603538487e3b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_14f16df8d0154f0aa2e7603538487e3b = echarts.init(document.getElementById('14f16df8d0154f0aa2e7603538487e3b'), 'light', {renderer: 'canvas'});
#
# var option_14f16df8d0154f0aa2e7603538487e3b = {
#     "title": [
#         {
#             "text": "Bar - datazoom - inside \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ### 10. bar datazoom both

# %%
days = ["{}일".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - both 예시")
bar.add(
     "",
    days,
    days_v1,
    is_datazoom_show=True,
    datazoom_type="both",
    datazoom_range=[10, 25],
    is_toolbox_show=False,
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1bcf00cab98e4d7c8b43a967a7b56004" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1bcf00cab98e4d7c8b43a967a7b56004 = echarts.init(document.getElementById('1bcf00cab98e4d7c8b43a967a7b56004'), 'light', {renderer: 'canvas'});
#
# var option_1bcf00cab98e4d7c8b43a967a7b56004 = {
#     "title": [
#         {
#             "text": "Bar - datazoom - both \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 1918179,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
# ...

# %% [markdown]
# ### 11. test bar datazoom xaxis and yaxis

# %%
days = ["{}일".format(i) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - xaxis/yaxis 예시")
bar.add(
    "",
    days,
    days_v1,
    # 묵시적 X 축, 가로 방향
    is_datazoom_show=True,
    datazoom_type="slider",
    datazoom_range=[10, 25],
    # 추가적인 dataZoom 제어 막대 추가, 세로 방향
    is_datazoom_extra_show=True,
    datazoom_extra_type="slider",
    datazoom_extra_range=[10, 25],
    is_toolbox_show=False,
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="75c516de006d4fbd823b5dbdf3c17036" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_75c516de006d4fbd823b5dbdf3c17036 = echarts.init(document.getElementById('75c516de006d4fbd823b5dbdf3c17036'), 'light', {renderer: 'canvas'});
#
# var option_75c516de006d4fbd823b5dbdf3c17036 = {
#     "title": [
#         {
#             "text": "Bar - datazoom - xaxis/yaxis \uc608\uc2dc",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 185498,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
# ...

# %% [markdown]
# ### 12. test bar extra html text label

# %%
bar = Bar("Column Chart", extra_html_text_label=["bar_extra_html_text_label"])
bar.add("가게A", CLOTHES, clothes_v1, is_stack=True)
bar.add("가게B", CLOTHES, clothes_v2, is_stack=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <p style="">bar_extra_html_text_label</p><div id="cb86c227c39b4615a3c543d36646c569" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cb86c227c39b4615a3c543d36646c569 = echarts.init(document.getElementById('cb86c227c39b4615a3c543d36646c569'), 'light', {renderer: 'canvas'});
#
# var option_cb86c227c39b4615a3c543d36646c569 = {
#     "title": [
#         {
#             "text": "Column Chart",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ### 13. test bar line color and with

# %%
bar = Bar("Column chart")
bar.add(
    "가게A",
    CLOTHES,
    clothes_v1,
    xaxis_line_color="green",
    xaxis_line_width=5,
    xaxis_label_textcolor="black"
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="45bba22b54fc48198a02b5bfa41a84c4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_45bba22b54fc48198a02b5bfa41a84c4 = echarts.init(document.getElementById('45bba22b54fc48198a02b5bfa41a84c4'), 'light', {renderer: 'canvas'});
#
# var option_45bba22b54fc48198a02b5bfa41a84c4 = {
#     "title": [
#         {
#             "text": "Column chart",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
# ...
